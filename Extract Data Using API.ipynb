# %%
import requests
import pandas as pd
import json
from prettytable import PrettyTable

# %%
# Create Pretty Table Object

# %%
tableobj=PrettyTable()
keyVal='fd7524aa-31c7-41dc-9cb2-16acfdbbdc48'

# %%
api_endpoint="https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY="
api_endpoint+=keyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=fd7524aa-31c7-41dc-9cb2-16acfdbbdc48'

# %%
json_Data=requests.get(api_endpoint).json()
json_Data
# Out:
# {'status': {'timestamp': '2021-09-10T19:37:03.983Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 16,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 6535},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 8833,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channels',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'galaxy-digital-portfolio',
#     'huobi-capital',
#     'alameda-research-portfolio',
# ...

# %%
cryptodata=json_Data['data']
cryptodata
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 8833,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channels',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'galaxy-digital-portfolio',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
# ...

# %%
lisst=list()
type(lisst)
lisst
# Out:
# []

# %%
for currency in cryptodata:
    currency_name=currency['name']
    currency_price=currency['quote']['USD']['price']
    currency_change_1h=currency['quote']['USD']['percent_change_1h']
    currency_change_24h=currency['quote']['USD']['percent_change_1h']
    currency_change_7d=currency['quote']['USD']['percent_change_1h']
    currency_change_30d=currency['quote']['USD']['percent_change_1h']
    tableobj.add_row([currency_name,currency_price,currency_change_1h,currency_change_24h,currency_change_7d,currency_change_30d])
# Out:
# [['Bitcoin', '45601.30504030344', '-0.20684708', '-0.20684708', '-0.20684708', '-0.20684708']]

# %%
tableobj.field_names=["Currency Name","Current Price","Curr 1h change","Curr 24h change","Curr 7d change","Curr 30d change"]

# %%
print(tableobj)
# Out:
# +-----------------------+--------------------+----------------+-----------------+----------------+-----------------+
# |     Currency Name     |   Current Price    | Curr 1h change | Curr 24h change | Curr 7d change | Curr 30d change |
# +-----------------------+--------------------+----------------+-----------------+----------------+-----------------+
# |        Bitcoin        | 45601.30504030344  |  -0.20684708   |   -0.20684708   |  -0.20684708   |   -0.20684708   |
# |        Ethereum       | 3320.3280047342923 |  -0.43924669   |   -0.43924669   |  -0.43924669   |   -0.43924669   |
# |        Cardano        |  2.3998269114711   |   -0.8520421   |    -0.8520421   |   -0.8520421   |    -0.8520421   |
# |         Tether        |  1.00019648420347  |  -0.02164238   |   -0.02164238   |  -0.02164238   |   -0.02164238   |
# |      Binance Coin     | 406.41114069997764 |  -0.42920144   |   -0.42920144   |  -0.42920144   |   -0.42920144   |
# ...
